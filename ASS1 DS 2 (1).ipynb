# %%
ADWAITA PATANE 
231061003
ELECTRONICS
ASSIGNMENT 1 DATASET 2

# %%
TITLE OF DATASET:
Crimes Against Women in India Dataset

# %%
WHY THIS PROBLEM AND WHAT WILL IT SOLVE : 
Crimes against women remain a pressing issue globally, especially in countries like India, where there are socio-cultural barriers to women's safety. By analyzing historical data, policymakers and researchers can develop interventions to address these issues. Additionally, understanding the factors contributing to these crimes can help in formulating more effective prevention strategies.The primary goal is to understand trends in crimes against women over time, across different states in India, and for various types of crimes. The objective is to identify patterns, outliers, and potential areas for policy intervention to reduce the rates of these crimes.

# %%
DOMAIN KNOWLEDGE: 
-Criminal Justice: An understanding of laws related to crimes against women (e.g., rape, domestic violence, dowry deaths) and how they are reported and prosecuted.
-Social and Political Context: Insights into societal norms, state-wise differences in reporting practices, and governmental policies impacting women's safety.
-Statistical Analysis: Knowledge of data analysis, correlation, and trends, especially related to demographic and crime data.
-Data Science: Familiarity with tools for data manipulation, cleaning, and visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline 
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
data = pd.read_csv('CrimesOnWomenData.csv')

# %%
data
# Out:
#      Unnamed: 0              State  Year  Rape   K&A   DD   AoW   AoM    DV  \
# 0             0     ANDHRA PRADESH  2001   871   765  420  3544  2271  5791
# 1             1  ARUNACHAL PRADESH  2001    33    55    0    78     3    11
# 2             2              ASSAM  2001   817  1070   59   850     4  1248
# 3             3              BIHAR  2001   888   518  859   562    21  1558
# 4             4       CHHATTISGARH  2001   959   171   70  1763   161   840
# ..          ...                ...   ...   ...   ...  ...   ...   ...   ...
# 731         731         D&N Haveli  2021  1250  4083  141  2068   417  4731
# 732         732        Daman & Diu  2021   315   904   16  1851    10   501
# 733         733           Delhi UT  2021     2     1    0     5     1     9
# 734         734        Lakshadweep  2021     0     0    0     1     1     3
# 735         735         Puducherry  2021     2     0    2    31     3    12
#
#      WT
# 0     7
# 1     0
# 2     0
# 3    83
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 736 entries, 0 to 735
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  736 non-null    int64
#  1   State       736 non-null    object
#  2   Year        736 non-null    int64
#  3   Rape        736 non-null    int64
#  4   K&A         736 non-null    int64
#  5   DD          736 non-null    int64
#  6   AoW         736 non-null    int64
#  7   AoM         736 non-null    int64
#  8   DV          736 non-null    int64
#  9   WT          736 non-null    int64
# dtypes: int64(9), object(1)
# memory usage: 57.6+ KB

# %%
DATA UNDERSTANDING :
Structure: The dataset consists of 736 rows and 10 columns. It includes the following fields:
State: The state in India where the crime data was collected.
Year: The year for which the crime data was recorded.
Crimes: Categories of crimes such as Rape, Kidnapping & Abduction (K&A), Dowry Deaths (DD), Assault on Women (AoW), Domestic Violence (DV), and Women Trafficking (WT).
Granularity: The data is at the state-year level, and each row represents a record for a specific state and year.
Variables:
Categorical Variables: State
Numeric Variables: Year, Rape, K&A, DD, AoW, AoM, DV, WT

# %%
data = data.rename(columns={'K&A': 'Kidnapping and Abduction', 
                        'DD': 'Dowry Deaths', 
                        'AoW': 'Assault against Women', 
                        'AoM': 'Assault against Modesty of Women',
                        'DV':'Domestic Violence',
                        'WT':'Women Trafficking'
})
data
# Out:
#      Unnamed: 0              State  Year  Rape  Kidnapping and Abduction  \
# 0             0     ANDHRA PRADESH  2001   871                       765
# 1             1  ARUNACHAL PRADESH  2001    33                        55
# 2             2              ASSAM  2001   817                      1070
# 3             3              BIHAR  2001   888                       518
# 4             4       CHHATTISGARH  2001   959                       171
# ..          ...                ...   ...   ...                       ...
# 731         731         D&N Haveli  2021  1250                      4083
# 732         732        Daman & Diu  2021   315                       904
# 733         733           Delhi UT  2021     2                         1
# 734         734        Lakshadweep  2021     0                         0
# 735         735         Puducherry  2021     2                         0
#
#      Dowry Deaths  Assault against Women  Assault against Modesty of Women  \
# ...

# %%
pd.DataFrame({'count': data.shape[0], 
              'nulls': data.isnull().sum(), 
              'nulls%': data.isnull().mean() * 100, 
              'cardinality': data.nunique(),
             })
# Out:
#                                   count  nulls  nulls%  cardinality
# Unnamed: 0                          736      0     0.0          736
# State                               736      0     0.0           70
# Year                                736      0     0.0           21
# Rape                                736      0     0.0          498
# Kidnapping and Abduction            736      0     0.0          491
# Dowry Deaths                        736      0     0.0          319
# Assault against Women               736      0     0.0          505
# Assault against Modesty of Women    736      0     0.0          322
# Domestic Violence                   736      0     0.0          488
# Women Trafficking                   736      0     0.0          124

# %% [markdown]
# EXPLORATORY DATA ANALYSIS

# %%
data.describe()
# Out:
#        Unnamed: 0         Year         Rape  Kidnapping and Abduction  \
# count  736.000000   736.000000   736.000000                736.000000
# mean   367.500000  2011.149457   727.855978               1134.542120
# std    212.609188     6.053453   977.024945               1993.536828
# min      0.000000  2001.000000     0.000000                  0.000000
# 25%    183.750000  2006.000000    35.000000                 24.750000
# 50%    367.500000  2011.000000   348.500000                290.000000
# 75%    551.250000  2016.000000  1069.000000               1216.000000
# max    735.000000  2021.000000  6337.000000              15381.000000
#
#        Dowry Deaths  Assault against Women  Assault against Modesty of Women  \
# count    736.000000             736.000000                        736.000000
# mean     215.692935            1579.115489                        332.722826
# std      424.927334            2463.962518                        806.024551
# ...

# %% [markdown]
# CRIME TREND

# %%
crime = data.groupby('Year').sum()

plt.figure(figsize=(15, 6))
sns.lineplot(data=crime)
plt.title('Crimes Against Women (2001-2021)')
plt.xlabel('Year')
plt.ylabel('Number of Crimes')
years = list(range(2001, 2022, 1)) 
plt.xticks(ticks=years, rotation=45)
plt.legend(title='Crime Type', bbox_to_anchor=(1, 1), loc='upper left')
plt.show()

# %%
data.groupby(['Year']).agg({
    'Rape': 'sum',
    'Kidnapping and Abduction': 'sum',
    'Dowry Deaths': 'sum',
    'Assault against Women': 'sum',
    'Assault against Modesty of Women': 'sum',
    'Domestic Violence': 'sum',
    'Women Trafficking': 'sum'
}).plot(kind = 'bar', figsize=(23, 10))
plt.title('Crime Proportion in Top 10 States by Total Number of Crimes')
plt.xlabel('State')
plt.ylabel('Number of Crimes')
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# STATE WISE CRIME ANALYSIS

# %%
data.groupby('State').sum().sort_values(by='Rape', ascending=False).head(10)
# Out:
#                 Unnamed: 0   Year   Rape  Kidnapping and Abduction  \
# State
# Madhya Pradesh        5863  22176  43552                     50457
# Rajasthan             5951  22176  31850                     36059
# Uttar Pradesh         6006  22176  30641                    101701
# MADHYA PRADESH        1660  20055  29256                      7028
# Maharashtra           5874  22176  24806                     38061
# Assam                 5742  22176  19428                     55094
# Kerala                5852  22176  18888                     12593
# Punjab                5940  22176  18762                     20432
# WEST BENGAL           1800  20055  16378                     13894
# Odisha                5929  22176  15950                     23928
#
#                 Dowry Deaths  Assault against Women  \
# State
# Madhya Pradesh          5834                  85442
# Rajasthan               3695                  41801
# Uttar Pradesh          21357                  76654
# ...

# %%
data.groupby('State').sum().plot(kind='bar', stacked=True, figsize=(12,8))
# Out:
# <Axes: xlabel='State'>

# %%
DATA PROCESSING PIPELINE:
Data Collection:

The data likely comes from government or law enforcement agencies that track crimes against women in India. It includes records from different states over several years.
Data Cleaning:

Missing values: If any crime data is missing, we either fill in the gaps with average values or remove those entries.
Outliers: We check for unusual or extreme values that could be errors and decide if they should be corrected.
Duplicates: Remove any duplicate rows that could skew our analysis.
Inconsistencies: Ensure data is consistent (e.g., checking if state names are spelled correctly or the years are accurate).
Exploratory Data Analysis (EDA):

Histograms & Bar Charts: Use these to show the distribution of different crimes across states and years.
Scatter Plots: Visualize how different crimes relate to each other (e.g., states with more domestic violence might also report more dowry deaths).
Box Plots: Identify any outliers or unusual data patterns across years or states.
Correlation Heatmaps: Check if there are any strong relationships between different types of crimes.
Data Modeling:

Once we've explored the data, we could predict future trends (e.g., using linear regression to forecast crime rates) or classify states with similar crime patterns (e.g., using K-means clustering to group states).
Evaluation:

In simple analysis, we check if the insights match real-world trends. For predictive models, we'd evaluate the accuracy of predictions using methods like cross-validation and error metrics (e.g., Root Mean Square Error or RMSE).
Deployment:

The findings can be shared with policymakers and law enforcement to help create strategies for reducing crime.

# %% [markdown]
# CONTUNIATION OF ASSIGNMENT 1 INTO ASSIGNMENT 2

# %% [markdown]
# WHATS DONE AND ACHIEVED BELOW
# 1. Importing Necessary Libraries
# Libraries Used:
# Use pandas and numpy for data manipulation and numerical operations.
# Utilize seaborn and matplotlib.pyplot for visualizations.
# Import scipy.stats for statistical tests, such as the chi-square test.
# Use sklearn.feature_selection.chi2 for feature selection using the chi-square test.
# Purpose: These libraries are essential for data handling, statistical analysis, and visualization.
# 2. Loading and Displaying the Dataset
# Action: Load the dataset from a CSV file into a pandas DataFrame.
# Purpose: This step brings the data into a format that can be easily manipulated and analyzed.
# Importance: This initial step helps you inspect the data structure and understand what you’re working with.
# 3. Exploring the Dataset
# Action: Display basic dataset information, including column names, data types, and the number of non-null values. Additionally, show the first few rows of data for inspection.
# Purpose: Provides an overview of the dataset structure and initial insights into its content.
# Importance: Understanding the dataset helps identify data quality issues and gives an idea of what features are available.

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import chi2_contingency
from sklearn.feature_selection import chi2

# Load the dataset
file_path = 'CrimesOnWomenData.csv'  # Path to the uploaded file
data = pd.read_csv(file_path)

# Display dataset information
print("Dataset Overview:")
print(data.info())
print("\nFirst 5 rows of the dataset:")
print(data.head())
# Out:
# Dataset Overview:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 736 entries, 0 to 735
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  736 non-null    int64
#  1   State       736 non-null    object
#  2   Year        736 non-null    int64
#  3   Rape        736 non-null    int64
#  4   K&A         736 non-null    int64
#  5   DD          736 non-null    int64
#  6   AoW         736 non-null    int64
#  7   AoM         736 non-null    int64
#  8   DV          736 non-null    int64
#  9   WT          736 non-null    int64
# dtypes: int64(9), object(1)
# memory usage: 57.6+ KB
# None
#
# First 5 rows of the dataset:
#    Unnamed: 0              State  Year  Rape   K&A   DD   AoW   AoM    DV  WT
# 0           0     ANDHRA PRADESH  2001   871   765  420  3544  2271  5791   7
# 1           1  ARUNACHAL PRADESH  2001    33    55    0    78     3    11   0
# ...

# %% [markdown]
# WHATS DONE AND ACHIEVED BELOW
# 4. Dropping Redundant Columns
# Action: Remove unnecessary columns (e.g., unnamed index columns).
# Purpose: Simplifies the dataset and helps focus on meaningful data.
# Importance: Reduces clutter and potential issues with irrelevant data during analysis.
# 5. Descriptive Statistics
# Action: Generate summary statistics (e.g., mean, median, min, max) for numerical and categorical columns and calculate the mode.
# Purpose: Provides a detailed overview of each column's distribution and central tendency.
# Importance: Helps identify outliers, skewness, and general trends within the data.
# 6. Visualizing Descriptive Statistics
# Action: Create bar charts to represent the descriptive statistics of numerical features.
# Purpose: Visual representation of data allows for easier comparison and understanding of the dataset’s distribution.
# Importance: Charts help to identify trends and distributions more effectively than raw data tables.

# %%
# Drop unnamed or redundant columns if applicable
data = data.loc[:, ~data.columns.str.contains('^Unnamed')]

# Descriptive Statistics
print("\nDescriptive Statistics:")
descriptive_stats = data.describe(include='all').transpose()
modes = data.mode().iloc[0]
descriptive_stats['Mode'] = modes
print(descriptive_stats)

# Visualize Descriptive Statistics
descriptive_stats_numeric = data.describe()
descriptive_stats_numeric.plot(kind='bar', figsize=(15, 6))
plt.title('Descriptive Statistics of Numeric Features')
plt.xticks(rotation=45)
plt.show()
# Out:
# Descriptive Statistics:
#        count unique                top freq         mean          std     min  \
# State    736     70  Arunachal Pradesh   11          NaN          NaN     NaN
# Year   736.0    NaN                NaN  NaN  2011.149457     6.053453  2001.0
# Rape   736.0    NaN                NaN  NaN   727.855978   977.024945     0.0
# K&A    736.0    NaN                NaN  NaN   1134.54212  1993.536828     0.0
# DD     736.0    NaN                NaN  NaN   215.692935   424.927334     0.0
# AoW    736.0    NaN                NaN  NaN  1579.115489  2463.962518     0.0
# AoM    736.0    NaN                NaN  NaN   332.722826   806.024551     0.0
# DV     736.0    NaN                NaN  NaN  2595.078804  4042.004953     0.0
# WT     736.0    NaN                NaN  NaN    28.744565     79.99966     0.0
#
#           25%     50%      75%      max           Mode
# State     NaN     NaN      NaN      NaN  A & N Islands
# ...

# %% [markdown]
# WHATS DONE AND ACHIEVED BELOW
# 7. Calculating Mean, Median, and Quantiles
# Action: Print the mean, median, and quantile values (25th, 50th, 75th percentiles) for numerical columns.
# Purpose: Gives an understanding of data spread and the central location of data points.
# Importance: Identifies skewness and data characteristics that may impact analysis and modeling.

# %%
# Additional descriptive metrics
print("\nMean Values:")
print(data.mean(numeric_only=True))

print("\nMedian Values:")
print(data.median(numeric_only=True))

print("\nQuantiles (25%, 50%, 75%):")
print(data.select_dtypes(include=[np.number]).quantile([0.25, 0.5, 0.75]))
# Out:
# Mean Values:
# Year    2011.149457
# Rape     727.855978
# K&A     1134.542120
# DD       215.692935
# AoW     1579.115489
# AoM      332.722826
# DV      2595.078804
# WT        28.744565
# dtype: float64
#
# Median Values:
# Year    2011.0
# Rape     348.5
# K&A      290.0
# DD        29.0
# AoW      387.5
# AoM       31.0
# DV       678.5
# WT         0.0
# dtype: float64
#
# Quantiles (25%, 50%, 75%):
#         Year    Rape      K&A     DD      AoW    AoM      DV    WT
# 0.25  2006.0    35.0    24.75    1.0    34.00    3.0    13.0   0.0
# 0.50  2011.0   348.5   290.00   29.0   387.50   31.0   678.5   0.0
# 0.75  2016.0  1069.0  1216.00  259.0  2122.25  277.5  3545.0  15.0

# %% [markdown]
# WHATS DONE AND ACHIEVED BELOW
# 8. Segregating Target and Explanatory Variables
# Action: Identify the target variable(s) (e.g., Rape, DV) and explanatory variables by dropping unrelated columns.
# Purpose: Sets up the data for correlation analysis and chi-square tests.
# Importance: Helps focus analysis on the relationship between features and the target variables.

# %%
# Segregate target variable and explanatory variables
# Assuming 'Rape' is one target variable and 'DV' is another if present
target_variable_rape = data['Rape'] if 'Rape' in data.columns else None
target_variable_dv = data['DV'] if 'DV' in data.columns else None
explanatory_variables = data.drop(columns=['Rape', 'DV', 'State', 'Year'], errors='ignore')

# %% [markdown]
# WHATS DONE AND ACHIEVED BELOW
# 9. Correlation Analysis
# Action: Calculate and display correlation between the target variable and the explanatory variables.
# Purpose: Shows which features have a strong linear relationship with the target, which is valuable for predictive modeling.
# Importance: Correlation helps identify important variables and those that may not contribute much to model performance.

# %%
# Correlation Analysis
print("\nCorrelation Analysis:")
if target_variable_rape is not None:
    correlation_results_rape = explanatory_variables.corrwith(target_variable_rape)
    print("Correlation with Rape:")
    print(correlation_results_rape)
    sns.barplot(x=correlation_results_rape.index, y=correlation_results_rape.values)
    plt.title('Correlation with Rape')
    plt.xticks(rotation=45)
    plt.show()

if target_variable_dv is not None:
    correlation_results_dv = explanatory_variables.corrwith(target_variable_dv)
    print("\nCorrelation with DV:")
    print(correlation_results_dv)
    sns.barplot(x=correlation_results_dv.index, y=correlation_results_dv.values)
    plt.title('Correlation with DV')
    plt.xticks(rotation=45)
    plt.show()
# Out:
# Correlation Analysis:
# Correlation with Rape:
# K&A    0.700730
# DD     0.553497
# AoW    0.804336
# AoM    0.458025
# WT     0.219218
# dtype: float64
# Correlation with DV:
# K&A    0.685999
# DD     0.487465
# AoW    0.631558
# AoM    0.419300
# WT     0.280839
# dtype: float64

# %% [markdown]
# WHATS DONE AND ACHIEVED BELOW
# 10. Chi-Square Test for Independence
# Action: Perform chi-square tests to assess if categorical explanatory variables are independent of the target variable.
# Purpose: Determines if there is a statistically significant association between features and the target.
# Importance: Useful for feature selection when dealing with categorical data to identify relevant features.
# 11. Converting Chi-Square Results to a DataFrame
# Action: Format the chi-square test results into a structured DataFrame for easy viewing and analysis.
# Purpose: Makes it easier to inspect and compare the results across different features.
# Importance: Streamlines the process of identifying important features for further analysis.
# 12. Visualizing Chi-Square Test Results
# Action: Create bar charts or other visualizations of chi-square values for features.
# Purpose: Highlights which features show a stronger dependency on the target variable.
# Importance: Visualization helps to quickly identify and focus on significant features.

# %%
# Chi-square Test for Independence
chi_square_results = {}
for column in explanatory_variables.columns:
    if target_variable_rape is not None:
        contingency_table_rape = pd.crosstab(target_variable_rape, explanatory_variables[column])
        chi2_rape, p_rape, _, _ = chi2_contingency(contingency_table_rape)
        chi_square_results[f"{column}_Rape"] = {"Chi2 Value": chi2_rape, "P-Value": p_rape}

    if target_variable_dv is not None:
        contingency_table_dv = pd.crosstab(target_variable_dv, explanatory_variables[column])
        chi2_dv, p_dv, _, _ = chi2_contingency(contingency_table_dv)
        chi_square_results[f"{column}_DV"] = {"Chi2 Value": chi2_dv, "P-Value": p_dv}

# Convert Chi-square results to DataFrame
chi_square_summary = pd.DataFrame(chi_square_results).transpose()
print("\nChi-square Test Results:")
print(chi_square_summary)

# Visualize Chi-square Test Results
chi_square_summary['Chi2 Value'].plot(kind='bar', figsize=(15, 6))
plt.title('Chi-square Test Results')
plt.xticks(rotation=45)
plt.ylabel('Chi2 Value')
plt.show()
# Out:
# Chi-square Test Results:
#              Chi2 Value  P-Value
# K&A_Rape  299851.429601      0.0
# K&A_DV    306318.129227      0.0
# DD_Rape   213731.081868      0.0
# DD_DV     220208.015840      0.0
# AoW_Rape  300628.073303      0.0
# AoW_DV    303687.145629      0.0
# AoM_Rape  209262.277348      0.0
# AoM_DV    214708.740183      0.0
# WT_Rape    82258.083988      0.0
# WT_DV      86352.895223      0.0

# %% [markdown]
# WHATS DONE AND ACHIEVED BELOW
# 13. Feature Selection Using Chi-Square
# Action: Use the chi-square scores to select the most relevant features.
# Purpose: Identifies features that have the most significant relationships with the target variable.
# Importance: Reduces dimensionality and focuses analysis on key variables that contribute meaningfully.

# %%
# Feature Selection (Chi-Square)
print("\nFeature Selection using Chi-Square:")
if target_variable_dv is not None:
    chi_scores, p_values = chi2(explanatory_variables.select_dtypes(include=[np.number]), target_variable_dv)
    chi_feature_selection = pd.DataFrame({
        'Feature': explanatory_variables.select_dtypes(include=[np.number]).columns,
        'Chi2 Score': chi_scores,
        'P-Value': p_values
    })
    print(chi_feature_selection)
    chi_feature_selection.plot(x='Feature', y='Chi2 Score', kind='bar', figsize=(15, 6))
    plt.title('Feature Selection (Chi-Square)')
    plt.xticks(rotation=45)
    plt.ylabel('Chi2 Score')
    plt.show()
# Out:
# Feature Selection using Chi-Square:
#   Feature    Chi2 Score  P-Value
# 0     K&A  2.567669e+06      0.0
# 1      DD  6.063463e+05      0.0
# 2     AoW  2.809467e+06      0.0
# 3     AoM  1.428505e+06      0.0
# 4      WT  1.586764e+05      0.0

# %% [markdown]
# WHATS DONE AND ACHIEVED BELOW

# %%
# Correlation Matrix
print("\nCorrelation Matrix:")
correlation_matrix = data.select_dtypes(include=[np.number]).corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()
# Out:
# Correlation Matrix:

# %%
# Identify highly correlated variables
high_corr_vars = correlation_matrix[(correlation_matrix > 0.8) | (correlation_matrix < -0.8)]
print("\nHighly Correlated Variables:")
print(high_corr_vars)
# Out:
# Highly Correlated Variables:
#       Year      Rape  K&A   DD       AoW  AoM   DV   WT
# Year   1.0       NaN  NaN  NaN       NaN  NaN  NaN  NaN
# Rape   NaN  1.000000  NaN  NaN  0.804336  NaN  NaN  NaN
# K&A    NaN       NaN  1.0  NaN       NaN  NaN  NaN  NaN
# DD     NaN       NaN  NaN  1.0       NaN  NaN  NaN  NaN
# AoW    NaN  0.804336  NaN  NaN  1.000000  NaN  NaN  NaN
# AoM    NaN       NaN  NaN  NaN       NaN  1.0  NaN  NaN
# DV     NaN       NaN  NaN  NaN       NaN  NaN  1.0  NaN
# WT     NaN       NaN  NaN  NaN       NaN  NaN  NaN  1.0

# %%
# Save results to CSV
output_path = "Combined_Analysis_Report1.csv"
chi_square_summary.to_csv(output_path, index=False)
print(f"\nCombined analysis report saved to {output_path}")

# Save results to CSV
outputpath = "Combined_Analysis_Report2.csv"
chi_feature_selection.to_csv(outputpath, index=False)
print(f"\nCombined analysis report saved to {outputpath}")
# Out:
# Combined analysis report saved to Combined_Analysis_Report1.csv
#
# Combined analysis report saved to Combined_Analysis_Report2.csv

# %%
#Extra Stuff
# Segregate target variable and explanatory variables
target_variable = dataset['Rape']
explanatory_variables = dataset.drop(columns=['Rape', 'Unnamed: 0', 'State', 'Year'])

# Correlation Analysis
print("\nCorrelation Analysis:")
correlation_results = explanatory_variables.corrwith(target_variable)
print(correlation_results)

# Chi-square Test for Independence
chi_square_results = {}
for column in explanatory_variables.columns:
    contingency_table = pd.crosstab(target_variable, explanatory_variables[column])
    chi2, p, _, _ = chi2_contingency(contingency_table)
    chi_square_results[column] = {"Chi2 Value": chi2, "P-Value": p}

# Convert Chi-square results to DataFrame
chi_square_summary = pd.DataFrame(chi_square_results).transpose()
print("\nChi-square Test Results:")
print(chi_square_summary)

# Combine findings into a single DataFrame
report_data = {
    "Variable": correlation_results.index,
    "Correlation with Rape": correlation_results.values,
    "Chi2 Value": chi_square_summary["Chi2 Value"].values,
    "P-Value": chi_square_summary["P-Value"].values,
}
report_df = pd.DataFrame(report_data)

# Save results to CSV
output_path = "Rape_Analysis_Report.csv"
report_df.to_csv(output_path, index=False)
print(f"\nAnalysis report saved to {output_path}")
# Out:
# Correlation Analysis:
# K&A    0.700730
# DD     0.553497
# AoW    0.804336
# AoM    0.458025
# DV     0.680321
# WT     0.219218
# dtype: float64
#
# Chi-square Test Results:
#         Chi2 Value  P-Value
# K&A  299851.429601      0.0
# DD   213731.081868      0.0
# AoW  300628.073303      0.0
# AoM  209262.277348      0.0
# DV   306117.642220      0.0
# WT    82258.083988      0.0
#
# Analysis report saved to Rape_Analysis_Report.csv
